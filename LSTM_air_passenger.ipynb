# %% [markdown]
# ### Redes Neurais Artificiais
# ### Professor Ciniro Nametala - IFMG
#
# ## Previsão em séries temporais com Redes Neurais Recorrentes - Células LSTM
#
# Neste trabalho vamos utilizar o *dataset Air Passenger* disponível no [repositório de datasets do Kaggle](https://www.kaggle.com/datasets/rakannimer/air-passengers). O conjunto de dados "Airline Passengers" contém informações mensais sobre o número de passageiros de companhias aéreas ao longo de um período de tempo. Ele geralmente é usado para fins de previsão, onde os modelos de *machine learning* são treinados para prever a demanda futura de passageiros com base nos padrões históricos.
#
# A origem específica desse conjunto de dados remonta à década de 1940 e foi publicado originalmente por Box e Jenkins em seu livro *Time Series Analysis: Forecasting and Control* em 1976. Os dados representam o número mensal de passageiros de uma companhia aérea internacional entre os anos de 1949 e 1960.
#
# Esse conjunto de dados é popular entre os praticantes de *machine learning* devido à sua natureza temporal e à presença de tendências sazonais, tornando-o adequado para a aplicação e teste de algoritmos de previsão. O *dataset* possui 143 valores e duas colunas:
# 1. Mês
# 2. Quantidade de passageiros
#
# Opcionalmente você pode também comentar e descomentar partes do código a seguir para usar a série temporal de preço de fechamento diário da ação do Banco do Brasil (BBAS3) no período entre 02/01/2009 e 04/11/2013. Os valores foram retirados da ferramenta MetaTrader. Neste caso, o *dataset* possui as colunas:
# 1. Data
# 2. Abertura
# 3. Máximo
# 4. Mínimo
# 5. Fechamento
# 6. Volume

# %% [markdown]
# ## 1. Preparação do ambiente

# %% [markdown]
# ### 1.1 Configurações de ambiente

# %%
#funcao para deixar o jupyter com celulas preenchendo toda a tela
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#cria a pasta para armazenar o checkpoint e os modelos treinados
import os
os.makedirs("models", exist_ok=True)

# %% [markdown]
# ### 1.2 Importação de pacotes

# %%
#para exportar o requeriments
import subprocess
import sys

#bibliotecas para trabalhar com dados e graficos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

#bibliotecas do scikit-learn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

#biblioteca para exportacoes e importacoes de arquivos
from joblib import dump, load

#utilitario de GPU para Windows
#from numba import cuda

#biblioteca para implementar uma barra de progresso
import progressbar

#biblioteca para tocar sons
import pygame

#bibliotecas para deep learning
import tensorflow.keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, LSTM, GRU, Bidirectional, Dense

from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

#bibliotecas para plotar graficos do keras
import pydot as pyd
from tensorflow.keras.utils import plot_model, model_to_dot
tensorflow.keras.utils.pydot = pyd
# Out:
# /opt/anaconda3/envs/dl_tf/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 1.3 Verificando versões

# %%
import sys
print(f"Python version: {sys.version}")

import numpy as np
print(f"NumPy version: {np.__version__}")

import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")

import pandas as pd
print(f"Pandas version: {pd.__version__}")

import matplotlib
print(f"Matplotlib version: {matplotlib.__version__}")

import seaborn as sns
print(f"Seaborn version: {sns.__version__}")
# Out:
# Python version: 3.11.0 | packaged by conda-forge | (main, Jan 14 2023, 12:26:40) [Clang 14.0.6 ]
# NumPy version: 1.26.4
# TensorFlow version: 2.15.0
# Pandas version: 2.3.3
# Matplotlib version: 3.10.7
# Seaborn version: 0.13.2

# %% [markdown]
# ### 1.4 Checagem de GPU

# %%
# Verificação de GPU (sem warning)
gpus = tf.config.list_physical_devices('GPU')
print(f"TensorFlow encontrou GPUs: {len(gpus) > 0}")
print(f"Dispositivos GPU TensorFlow: {gpus}")
# Out:
# TensorFlow encontrou GPUs: True
# Dispositivos GPU TensorFlow: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [raw]
# #checa a GPU e limpa ela se usar placas INTEL em Windows
# device = cuda.get_current_device()
# print(device)
# device.reset()
# !nvidia-smi

# %% [markdown]
# ### 1.5 Escolha do dataset

# %%
use_dataset = 'AP' #AP para AirPassenger ou BB para Banco do Brasil
new_model = True   #gerar um novo modelo ou usar um pronto?

# %% [markdown]
# ## 2. Importações de dados

# %% [markdown]
# ### 2.1 Opção a) Air Passenger

# %%
if (use_dataset == 'AP'):
    col_names = ['mes', 'passageiros']

    # importação de dados
    data = pd.read_csv('dataset/airline-passengers.csv', header=0, names=col_names)

    # converte tudo para número
    data['passageiros'] = data['passageiros'].astype("float32")

    x_names = 'passageiros'

    data

# %%
if (use_dataset == 'AP'):
    #ajustando o dataset para treinamento com o keras
    serie = data['passageiros'].values.reshape(-1, 1)

    print(serie.shape)
# Out:
# (144, 1)

# %% [markdown]
# ### 2.2 Opção b) Banco do Brasil S.A.

# %%
if (use_dataset == 'BB'):
    col_names = ['data','abertura','maximo','minimo','fechamento','volume']

    # importação de dados
    data = pd.read_csv('dataset/bbas3.csv', header=0, names=col_names, sep=';')

    #remove as colunas nao usadas
    data = data.drop('abertura', axis=1)
    data = data.drop('maximo', axis=1)
    data = data.drop('minimo', axis=1)
    data = data.drop('volume', axis=1)

    # converte tudo para número
    data['fechamento'] = data['fechamento'].astype("float32")

    x_names = 'fechamento'

    #ajustando o dataset para treinamento com o keras
    serie = data['fechamento'].values.reshape(-1, 1)

    print(serie.shape)

# %% [markdown]
# ## 3. Configurações do experimento

# %%
#parametros
norm_method = 'asinh' #log, asinh
range_adjust = (0,1)

if (use_dataset == 'AP'):
    #AIR PASSENGERS-------
    size_hist_window = 12 
    size_forw_window = 1
    model_name = 'dnn_air_pass.h5'

if (use_dataset == 'BB'):
    #BANCO DO BRASIL------
    size_hist_window = 20 
    size_forw_window = 10
    model_name = 'dnn_bbas3.h5'

#realizar ajuste dos dados
data_adjust_exec = True

#exportar os datasets tratados
export_frames = True

# %% [markdown]
# ## 4. Análise de dados

# %%
plt.plot(serie)
plt.xlabel("tempo")
plt.ylabel(x_names)
plt.show()

# %% [markdown]
# ### 4.1 Sumarização estatística

# %%
def sumarizacao(serie, column):
    stats = []

    maximum = round(np.max(serie), 2)
    minimum = round(np.min(serie), 2)
    mean = round(np.mean(serie), 2)
    median = round(np.median(serie), 2)
    std = round(np.std(serie), 2)
    stats.append([column, maximum, minimum, mean, median, std])

    headers = ['Coluna', 'Máximo', 'Mínimo', 'Média', 'Mediana', 'Desvio Padrão']

    table = tabulate(stats, headers, tablefmt="pipe")
    print(table)

# %%
sumarizacao(serie, x_names)
# Out:
# | Coluna      |   Máximo |   Mínimo |   Média |   Mediana |   Desvio Padrão |
# |:------------|---------:|---------:|--------:|----------:|----------------:|
# | passageiros |      622 |      104 |   280.3 |     265.5 |          119.55 |

# %%
data.boxplot(column=x_names, figsize=(4, 4))
plt.tight_layout()
plt.show()

# %%
data.hist(column=x_names, figsize=(4, 4))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 Verificando integridade dos dados

# %%
missing_counts = data.isnull().sum()
print("Total de dados faltantes por atributo:")
print(missing_counts)
# Out:
# Total de dados faltantes por atributo:
# mes            0
# passageiros    0
# dtype: int64

# %% [markdown]
# ### 4.3 Aplicando normalizacao e escala [0, 1]

# %%
def varianceEstabilization(serie, method):
    if method == 'asinh':
        return np.arcsinh(serie)
    elif method == 'log':
        return np.log(serie)
    else:
        return serie
    
def inverseVarianceEstabilization(serie, method):
    if method == 'asinh':
        return np.sinh(serie)
    elif method == 'log':
        return np.exp(serie)
    else:
        return serie

# %%
#ajuste de dados
if data_adjust_exec:
    serie = varianceEstabilization(serie, norm_method)
    scaler = MinMaxScaler(feature_range=range_adjust)
    serie = scaler.fit_transform(serie)
    
plt.plot(serie)
plt.xlabel("tempo")
plt.ylabel(x_names + " log[0, 1]")
plt.show()

# %%
#desconversao de dados
serie_original = scaler.inverse_transform(serie)
serie_original = inverseVarianceEstabilization(serie_original, norm_method)

plt.plot(serie_original)
plt.xlabel("tempo")
plt.ylabel(x_names + " Quantidade")
plt.show()

# %% [markdown]
# ## 5. Separacao dos conjuntos de dados (treino/validação e teste)

# %%
#separa os conjuntos de treino/validacao e teste
trainval_size = int(len(serie) * 0.70)
test_size = len(serie) - trainval_size
trainval, test = serie[0:trainval_size,:], serie[trainval_size:len(serie),:]

print(trainval.shape)
print(test.shape)
# Out:
# (100, 1)
# (44, 1)

# %% [markdown]
# ### 5.1 Criação das janelas móveis

# %%
#cria os frames com base numa janela historica de dados
def create_frames(serie, back_window_size, forw_window_size):
    x_frames, y_frames = [], []
    
    for i in range(0, len(serie) - back_window_size - 1, forw_window_size):
        x_frames.append(serie[i:(i + back_window_size), 0])
        y_frames.append(serie[(i + back_window_size):(i + back_window_size) + forw_window_size, 0])
        
    return np.array(x_frames), np.array(y_frames)

# %%
#cria os frames
x_trainval, y_trainval = create_frames(trainval, size_hist_window, size_forw_window)
x_test, y_test = create_frames(test, size_hist_window, size_forw_window)

print(x_trainval.shape)
print(y_trainval.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (87, 12)
# (87, 1)
# (31, 12)
# (31, 1)

# %%
serie[0:13]
# Out:
# array([[0.04143333],
#        [0.07061028],
#        [0.1332953 ],
#        [0.12044191],
#        [0.08464718],
#        [0.14585996],
#        [0.19726276],
#        [0.19726276],
#        [0.14998603],
#        [0.07532835],
#        [0.        ],
#        [0.07061028],
#        [0.05621219]], dtype=float32)

# %%
x_trainval[0:3]
# Out:
# array([[0.04143333, 0.07061028, 0.1332953 , 0.12044191, 0.08464718,
#         0.14585996, 0.19726276, 0.19726276, 0.14998603, 0.07532835,
#         0.        , 0.07061028],
#        [0.07061028, 0.1332953 , 0.12044191, 0.08464718, 0.14585996,
#         0.19726276, 0.19726276, 0.14998603, 0.07532835, 0.        ,
#         0.07061028, 0.05621219],
#        [0.1332953 , 0.12044191, 0.08464718, 0.14585996, 0.19726276,
#         0.19726276, 0.14998603, 0.07532835, 0.        , 0.07061028,
#         0.05621219, 0.10728574]], dtype=float32)

# %%
y_trainval[0:3]
# Out:
# array([[0.05621219],
#        [0.10728574],
#        [0.17017269]], dtype=float32)

# %%
#ajustando para atender aos requisitos de entrada da LSTM: (amostras, timesteps, features)
x_trainval = np.expand_dims(x_trainval, axis=2)
y_trainval = np.expand_dims(y_trainval, axis=2)
x_test = np.expand_dims(x_test, axis=2)
y_test = np.expand_dims(y_test, axis=2)

print(x_trainval.shape)
print(y_trainval.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (87, 12, 1)
# (87, 1, 1)
# (31, 12, 1)
# (31, 1, 1)

# %% [markdown]
# ## 6. Treinamento do modelo

# %% [markdown]
# ### 6.1 Construção do modelo

# %%
#-----------------
#CRIAÇÃO DO MODELO BASEADO EM LSTM
#-----------------

# Configurações de neurônios
units_lstm1 = 16
units_lstm2 = 32
units_lstm3 = 32
units_dense = 16

# Funções de ativação
actfunc_lstm1 = 'tanh'
actfunc_lstm2 = 'tanh'
actfunc_lstm3 = 'tanh'
actfunc_dense = 'tanh'
actfunc_output = 'tanh'

#inicializador
initializer = tensorflow.keras.initializers.LecunNormal(seed=42)

# Criação das entradas de treino+validação
inputs = Input(shape=(x_trainval.shape[1], x_trainval.shape[2]), name="x_train")

# Camada LSTM 1
layer_lstm1 = LSTM(units_lstm1, 
                    activation=actfunc_lstm1, 
                    return_sequences=True,
                    kernel_initializer=initializer)(inputs)

# Camada LSTM 2
layer_lstm2 = LSTM(units_lstm2, 
                    activation=actfunc_lstm2, 
                    return_sequences=True,
                    kernel_initializer=initializer)(layer_lstm1)

# Camada LSTM 3
layer_lstm3 = Bidirectional(LSTM(units_lstm3, 
                                activation=actfunc_lstm3, 
                                return_sequences=False,
                                kernel_initializer=initializer))(layer_lstm2)

# Camada densa final para ajustar o formato da saída
layer_dense = Dense(units_dense, activation=actfunc_dense)(layer_lstm3)

# Camada densa final para ajustar o formato da saída
layer_dense_out = Dense(y_trainval.shape[1], activation=actfunc_output)(layer_dense)

# Criação do modelo
model_trained = Model(inputs=inputs, outputs=layer_dense_out)
# Out:
# 2025-12-11 16:45:55.945577: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-12-11 16:45:55.945603: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-12-11 16:45:55.945607: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2025-12-11 16:45:55.945630: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-11 16:45:55.945641: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### 6.2 Inspecionando o modelo

# %% [markdown]
# h = 1
# h - 1 = 16
# entrada no neuronio seguinte = (1 + 16) = 17
# pesos entre a entrada e as celulas = 17 * 16 = 272
# para cada neuronio adiciona o bias = 272 + 16 = 288
# para cada portao = 288 * 4 = 1152

# %%
model_trained.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  x_train (InputLayer)        [(None, 12, 1)]           0
#
#  lstm (LSTM)                 (None, 12, 16)            1152
#
#  lstm_1 (LSTM)               (None, 12, 32)            6272
#
#  bidirectional (Bidirection  (None, 64)                16640
#  al)
#
#  dense (Dense)               (None, 16)                1040
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 25121 (98.13 KB)
# Trainable params: 25121 (98.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model_trained, show_shapes=True, show_layer_names=True, rankdir="TB")  #TB para plotar na vertical

# %% [markdown]
# ### 6.3 Otimização do modelo

# %%
if new_model:
    #com o AirPassenger não usa validacao
    if (use_dataset == 'AP'):
        cp = ModelCheckpoint(
            filepath='models/' + model_name + '_model_trained.weights.h5',
            save_weights_only=True,
            monitor='loss',
            mode='min',
            save_best_only=True
        )
        validation_size = 0.0

        es = EarlyStopping(monitor='loss', mode='min', patience=200)

    #com o Banco do Brasil usa validacao
    if (use_dataset == 'BB'):
        cp = ModelCheckpoint(
            filepath='models/' + model_name + '_model_trained.weights.h5',
            save_weights_only=True,
            monitor='val_loss',
            mode='min',
            save_best_only=True
        )
        validation_size = 0.2

        es = EarlyStopping(monitor='val_loss', mode='min', patience=200)

    
    opt = Adam(learning_rate=0.0001)
    model_trained.compile(optimizer=opt, loss='mean_squared_error')

    history = model_trained.fit(
        x_trainval,
        y_trainval,
        validation_split=validation_size,
        epochs=500,
        verbose=1,
        callbacks=[cp, es],
        batch_size=1,
        shuffle=False
    )

    np.save('models/' + model_name + '_history_model.npy', history.history)
    model_trained.load_weights('models/' + model_name + '_model_trained.weights.h5')
    model_trained.save('models/' + model_name + '.keras')
else:
    model_trained = load_model('models/' + model_name + '.keras')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 2025-12-11 16:45:57.847400: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-12-11 16:45:57.933884: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 87/87 [==============================] - 3s 11ms/step - loss: 0.0314
# Epoch 2/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0140
# Epoch 3/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0102
# Epoch 4/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0078
# Epoch 5/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0066
# Epoch 6/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0062
# Epoch 7/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0061
# Epoch 8/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0061
# Epoch 9/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0061
# Epoch 10/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0061
# Epoch 11/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0061
# Epoch 12/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0060
# Epoch 13/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0060
# Epoch 14/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0059
# Epoch 15/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0058
# Epoch 16/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0058
# Epoch 17/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0057
# Epoch 18/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0056
# Epoch 19/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0056
# Epoch 20/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0055
# Epoch 21/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0055
# Epoch 22/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0054
# Epoch 23/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0053
# Epoch 24/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0053
# Epoch 25/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0052
# Epoch 26/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0051
# Epoch 27/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0051
# Epoch 28/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0050
# Epoch 29/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0050
# Epoch 30/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0049
# Epoch 31/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0049
# Epoch 32/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0048
# Epoch 33/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0048
# Epoch 34/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0047
# Epoch 35/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0047
# Epoch 36/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0046
# Epoch 37/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0046
# Epoch 38/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0046
# Epoch 39/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0045
# Epoch 40/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0045
# Epoch 41/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0044
# Epoch 42/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0044
# Epoch 43/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0044
# Epoch 44/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0043
# Epoch 45/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0043
# Epoch 46/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0042
# Epoch 47/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0042
# Epoch 48/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0042
# Epoch 49/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0041
# Epoch 50/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0041
# Epoch 51/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0041
# Epoch 52/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0040
# Epoch 53/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0040
# Epoch 54/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0040
# Epoch 55/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0039
# Epoch 56/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0039
# Epoch 57/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0039
# Epoch 58/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 59/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 60/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 61/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 62/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 63/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 64/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0037
# Epoch 65/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0036
# Epoch 66/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0036
# Epoch 67/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0036
# Epoch 68/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0036
# Epoch 69/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 70/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 71/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0035
# Epoch 72/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 73/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 74/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 75/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 76/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 77/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 78/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 79/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0033
# Epoch 80/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 81/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 82/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 83/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 84/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 85/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 86/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 87/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0031
# Epoch 88/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 89/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 90/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 91/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 92/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 93/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 94/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 95/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 96/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 97/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 98/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 99/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 100/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 101/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 102/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 103/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 104/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 105/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 106/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 107/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 108/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 109/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 110/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 111/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 112/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 113/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 114/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 115/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 116/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 117/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 118/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 119/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 120/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 121/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 122/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 123/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 124/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0024
# Epoch 125/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 126/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 127/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 128/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 129/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 130/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 131/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 132/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 133/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 134/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 135/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 136/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0023
# Epoch 137/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 138/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 139/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 140/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 141/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 142/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 143/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 144/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 145/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 146/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 147/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 148/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 149/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 150/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 151/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 152/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 153/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 154/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 155/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 156/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 157/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 158/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 159/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 160/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 161/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 162/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 163/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 164/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 165/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 166/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 167/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 168/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 169/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0021
# Epoch 170/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 171/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 172/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 173/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 174/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 175/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 176/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 177/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 178/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 179/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 180/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 181/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 182/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 183/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 184/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 185/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 186/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 187/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 188/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 189/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 190/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 191/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 192/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 193/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 194/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 195/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 196/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 197/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 198/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 199/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 200/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 201/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 202/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 203/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0016
# Epoch 204/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 205/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 206/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 207/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 208/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 209/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 210/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 211/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 212/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 213/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 214/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 215/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 216/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 217/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 218/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 219/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 220/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 221/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 222/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 223/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 224/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 225/500
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 226/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 227/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 228/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 229/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 230/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 231/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 232/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 233/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 234/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 235/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 236/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 237/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 238/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 239/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 240/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 241/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 242/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 243/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 244/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 245/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 246/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 247/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 248/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 249/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 250/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 251/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 252/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 253/500
# 87/87 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 254/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 255/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 256/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 257/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0014
# Epoch 258/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 259/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 260/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 261/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 262/500
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 263/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 264/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 265/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 266/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 267/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 268/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 269/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 270/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 271/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 272/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 273/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 274/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 275/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 276/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 277/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 278/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 279/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 280/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 281/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 282/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 283/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 284/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 285/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 286/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 287/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 288/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 289/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 290/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 291/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 292/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0013
# Epoch 293/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 294/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 295/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 296/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 297/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 298/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 299/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 300/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 301/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 302/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 303/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 304/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 305/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 306/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 307/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 308/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 309/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0012
# Epoch 310/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 311/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 312/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 313/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 314/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 315/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 316/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 317/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 318/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 319/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 320/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 321/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 322/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 323/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 324/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 325/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 326/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 327/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 328/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 329/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 330/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 331/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 332/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 333/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 334/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 335/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 336/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 337/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 338/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 339/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0011
# Epoch 340/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0010
# Epoch 341/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0010
# Epoch 342/500
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0010
# Epoch 343/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0010
# Epoch 344/500
# 87/87 [==============================] - 1s 13ms/step - loss: 0.0010
# Epoch 345/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0010
# Epoch 346/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 347/500
# 87/87 [==============================] - 1s 11ms/step - loss: 0.0010
# Epoch 348/500
# 87/87 [==============================] - 1s 12ms/step - loss: 0.0010
# Epoch 349/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.9584e-04
# Epoch 350/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.8989e-04
# Epoch 351/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.8397e-04
# Epoch 352/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.7808e-04
# Epoch 353/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.7225e-04
# Epoch 354/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.6646e-04
# Epoch 355/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.6074e-04
# Epoch 356/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.5508e-04
# Epoch 357/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.4948e-04
# Epoch 358/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.4398e-04
# Epoch 359/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.3855e-04
# Epoch 360/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.3320e-04
# Epoch 361/500
# 87/87 [==============================] - 1s 13ms/step - loss: 9.2795e-04
# Epoch 362/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.2279e-04
# Epoch 363/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.1773e-04
# Epoch 364/500
# 87/87 [==============================] - 1s 11ms/step - loss: 9.1276e-04
# Epoch 365/500
# 87/87 [==============================] - 1s 11ms/step - loss: 9.0789e-04
# Epoch 366/500
# 87/87 [==============================] - 1s 12ms/step - loss: 9.0311e-04
# Epoch 367/500
# 87/87 [==============================] - 1s 13ms/step - loss: 8.9844e-04
# Epoch 368/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.9385e-04
# Epoch 369/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.8936e-04
# Epoch 370/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.8496e-04
# Epoch 371/500
# 87/87 [==============================] - 1s 13ms/step - loss: 8.8065e-04
# Epoch 372/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.7642e-04
# Epoch 373/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.7227e-04
# Epoch 374/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.6819e-04
# Epoch 375/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.6419e-04
# Epoch 376/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.6025e-04
# Epoch 377/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.5638e-04
# Epoch 378/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.5256e-04
# Epoch 379/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.4880e-04
# Epoch 380/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.4508e-04
# Epoch 381/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.4141e-04
# Epoch 382/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.3778e-04
# Epoch 383/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.3419e-04
# Epoch 384/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.3063e-04
# Epoch 385/500
# 87/87 [==============================] - 1s 13ms/step - loss: 8.2711e-04
# Epoch 386/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.2360e-04
# Epoch 387/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.2013e-04
# Epoch 388/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.1668e-04
# Epoch 389/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.1324e-04
# Epoch 390/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.0982e-04
# Epoch 391/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.0643e-04
# Epoch 392/500
# 87/87 [==============================] - 1s 12ms/step - loss: 8.0305e-04
# Epoch 393/500
# 87/87 [==============================] - 1s 12ms/step - loss: 7.9968e-04
# Epoch 394/500
# 87/87 [==============================] - 1s 12ms/step - loss: 7.9633e-04
# Epoch 395/500
# 87/87 [==============================] - 1s 12ms/step - loss: 7.9299e-04
# Epoch 396/500
# 87/87 [==============================] - 1s 12ms/step - loss: 7.8967e-04
# Epoch 397/500
# 87/87 [==============================] - 1s 13ms/step - loss: 7.8636e-04
# Epoch 398/500
# 87/87 [==============================] - 1s 12ms/step - loss: 7.8306e-04
# Epoch 399/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.7979e-04
# Epoch 400/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.7652e-04
# Epoch 401/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.7328e-04
# Epoch 402/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.7005e-04
# Epoch 403/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.6683e-04
# Epoch 404/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.6363e-04
# Epoch 405/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.6045e-04
# Epoch 406/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.5729e-04
# Epoch 407/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.5415e-04
# Epoch 408/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.5102e-04
# Epoch 409/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.4792e-04
# Epoch 410/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.4484e-04
# Epoch 411/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.4177e-04
# Epoch 412/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.3872e-04
# Epoch 413/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.3570e-04
# Epoch 414/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.3269e-04
# Epoch 415/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.2970e-04
# Epoch 416/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.2673e-04
# Epoch 417/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.2378e-04
# Epoch 418/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.2085e-04
# Epoch 419/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.1794e-04
# Epoch 420/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.1504e-04
# Epoch 421/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.1216e-04
# Epoch 422/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.0930e-04
# Epoch 423/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.0645e-04
# Epoch 424/500
# 87/87 [==============================] - 1s 11ms/step - loss: 7.0362e-04
# Epoch 425/500
# 87/87 [==============================] - 1s 12ms/step - loss: 7.0080e-04
# Epoch 426/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.9800e-04
# Epoch 427/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.9522e-04
# Epoch 428/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.9245e-04
# Epoch 429/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.8969e-04
# Epoch 430/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.8695e-04
# Epoch 431/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.8422e-04
# Epoch 432/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.8150e-04
# Epoch 433/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.7878e-04
# Epoch 434/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.7608e-04
# Epoch 435/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.7339e-04
# Epoch 436/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.7071e-04
# Epoch 437/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.6805e-04
# Epoch 438/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.6540e-04
# Epoch 439/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.6276e-04
# Epoch 440/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.6013e-04
# Epoch 441/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.5750e-04
# Epoch 442/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.5488e-04
# Epoch 443/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.5226e-04
# Epoch 444/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.4964e-04
# Epoch 445/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.4703e-04
# Epoch 446/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.4443e-04
# Epoch 447/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.4185e-04
# Epoch 448/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.3929e-04
# Epoch 449/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.3674e-04
# Epoch 450/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.3420e-04
# Epoch 451/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.3166e-04
# Epoch 452/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.2911e-04
# Epoch 453/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.2654e-04
# Epoch 454/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.2397e-04
# Epoch 455/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.2139e-04
# Epoch 456/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.1883e-04
# Epoch 457/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.1629e-04
# Epoch 458/500
# 87/87 [==============================] - 1s 11ms/step - loss: 6.1378e-04
# Epoch 459/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.1131e-04
# Epoch 460/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.0885e-04
# Epoch 461/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.0641e-04
# Epoch 462/500
# 87/87 [==============================] - 1s 13ms/step - loss: 6.0394e-04
# Epoch 463/500
# 87/87 [==============================] - 1s 12ms/step - loss: 6.0145e-04
# Epoch 464/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.9891e-04
# Epoch 465/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.9633e-04
# Epoch 466/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.9372e-04
# Epoch 467/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.9113e-04
# Epoch 468/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.8859e-04
# Epoch 469/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.8614e-04
# Epoch 470/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.8379e-04
# Epoch 471/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.8151e-04
# Epoch 472/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.7923e-04
# Epoch 473/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.7690e-04
# Epoch 474/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.7447e-04
# Epoch 475/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.7191e-04
# Epoch 476/500
# 87/87 [==============================] - 1s 11ms/step - loss: 5.6925e-04
# Epoch 477/500
# 87/87 [==============================] - 1s 11ms/step - loss: 5.6652e-04
# Epoch 478/500
# 87/87 [==============================] - 1s 11ms/step - loss: 5.6377e-04
# Epoch 479/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.6106e-04
# Epoch 480/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.5848e-04
# Epoch 481/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.5614e-04
# Epoch 482/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.5412e-04
# Epoch 483/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.5238e-04
# Epoch 484/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.5076e-04
# Epoch 485/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.4899e-04
# Epoch 486/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.4678e-04
# Epoch 487/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.4402e-04
# Epoch 488/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.4077e-04
# Epoch 489/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.3728e-04
# Epoch 490/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.3385e-04
# Epoch 491/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.3069e-04
# Epoch 492/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.2787e-04
# Epoch 493/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.2539e-04
# Epoch 494/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.2323e-04
# Epoch 495/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.2147e-04
# Epoch 496/500
# 87/87 [==============================] - 1s 11ms/step - loss: 5.2026e-04
# Epoch 497/500
# 87/87 [==============================] - 1s 11ms/step - loss: 5.1965e-04
# Epoch 498/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.1954e-04
# Epoch 499/500
# 87/87 [==============================] - 1s 12ms/step - loss: 5.1952e-04
# Epoch 500/500
# 87/87 [==============================] - 1s 13ms/step - loss: 5.1902e-04

# %% [markdown]
# ### 6.4 Avaliação do modelo com curva de convergência
#
# Descomente este código se você estiver realizando testes com conjunto de validação para ver a curva de convergência

# %%
history=np.load('models/' + model_name + '_history_model.npy', allow_pickle='TRUE').item()

sns.set(rc={'figure.figsize':(12, 6)})
sns.set_style('whitegrid')
sns.set_context('paper')

train_metric = history['loss']

if (use_dataset == 'BB'):
    valid_metric = history['val_loss']
    
name_metric = 'mse'

fig = plt.figure()

plt.plot(train_metric, label='TREINO')

if (use_dataset == 'BB'):
    plt.plot(valid_metric, label='VALIDAÇÃO')

plt.ylabel(name_metric.upper())
plt.xlabel('epoch')

if (use_dataset == 'BB'):
    plt.title('Treino vs. Validação usando: ' + name_metric.upper())
else:
    plt.title('Treino usando: ' + name_metric.upper())
    
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=2)

plt.show()

# %% [markdown]
# ## 7. Testando as previsões

# %% [markdown]
# ### 7.1 Gerando as previsões com o modelo treinado

# %%
test[0:13]
# Out:
# array([[0.68643403],
#        [0.78309846],
#        [0.8373506 ],
#        [0.8397505 ],
#        [0.7587261 ],
#        [0.6736901 ],
#        [0.6015568 ],
#        [0.655679  ],
#        [0.6622956 ],
#        [0.62489414],
#        [0.69735146],
#        [0.6752989 ],
#        [0.698894  ]], dtype=float32)

# %%
x_test[0:1]
# Out:
# array([[[0.68643403],
#         [0.78309846],
#         [0.8373506 ],
#         [0.8397505 ],
#         [0.7587261 ],
#         [0.6736901 ],
#         [0.6015568 ],
#         [0.655679  ],
#         [0.6622956 ],
#         [0.62489414],
#         [0.69735146],
#         [0.6752989 ]]], dtype=float32)

# %%
y_test[0:1]
# Out:
# array([[[0.698894]]], dtype=float32)

# %%
if (use_dataset == 'AP'):
    #AIR PASSENGER
    #pega os dados reais e volta para a escala original - air passenger
    y_true = scaler.inverse_transform(y_test.reshape(y_test.shape[0],1))
    y_true = inverseVarianceEstabilization(y_true, norm_method).flatten()

# %%
if (use_dataset == 'BB'):
    #BANCO DO BRASIL
    #pega os dados reais e volta para a escala original - bbas3
    y_true = scaler.inverse_transform(y_test.reshape(y_test.flatten().shape[0],1))
    y_true = inverseVarianceEstabilization(y_true, norm_method).flatten()

# %%
y_true
# Out:
# array([363.00006, 435.00003, 490.9999 , 504.99994, 403.9999 , 358.99994,
#        310.00006, 336.99997, 360.00003, 341.9999 , 406.00006, 395.99997,
#        419.99997, 471.99997, 548.0001 , 559.00006, 463.     , 407.00006,
#        361.99994, 405.     , 417.00003, 390.9999 , 419.     , 460.9999 ,
#        471.99997, 535.     , 622.0001 , 606.0001 , 508.0001 , 460.9999 ,
#        390.     ], dtype=float32)

# %%
y_true.shape
# Out:
# (31,)

# %%
#realiza as previsoes do modelo treinado no conjunto de testes e volta para a escala original
y_hat = model_trained.predict(x_test)
# Out:
# 1/1 [==============================] - 1s 736ms/step

# %%
#pega os dados previstos e coloca na escala original
y_hat = scaler.inverse_transform(y_hat)
y_hat = inverseVarianceEstabilization(y_hat, norm_method).flatten()
y_hat.shape
# Out:
# (31,)

# %% [markdown]
# ### 7.2 Avaliando as previsões

# %%
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def printRegressionMetrics(y_true, y_pred):
    
    MAPE = mape(y_true, y_pred)
    R2 = metrics.r2_score(y_true, y_pred)
    
    print('MAPE:')
    print(MAPE)
    print('R2:')
    print(R2)

# %%
printRegressionMetrics(y_true, y_hat)
# Out:
# MAPE:
# 8.119425922632217
# R2:
# 0.5730781555175781

# %%
if (use_dataset == 'AP'):
    #AIR PASSENGER
    #pega os valores reais anteriores ao ponto de previsao - air passenger
    y_true_trainval = y_trainval.flatten().reshape(len(y_trainval),1)
    y_true_trainval = scaler.inverse_transform(y_true_trainval)
    y_true_trainval = inverseVarianceEstabilization(y_true_trainval, norm_method).flatten()

# %%
if (use_dataset == 'BB'):
    #BANCO DO BRASIL
    #pega os valores reais anteriores ao ponto de previsao - bbas3
    y_true_trainval = y_trainval.flatten().reshape(len(y_trainval.flatten()),1)
    y_true_trainval = scaler.inverse_transform(y_true_trainval)
    y_true_trainval = inverseVarianceEstabilization(y_true_trainval, norm_method).flatten()

# %%
y_true_trainval.shape
# Out:
# (87,)

# %%
#cria um data table com os valores reais e preditos
df_forecast = pd.DataFrame()
df_forecast['y_true'] = np.hstack((y_true_trainval, y_true))
df_forecast['y_hat'] = np.hstack((y_true_trainval, y_hat))

df_forecast.shape
# Out:
# (118, 2)

# %%
sns.set(rc={'figure.figsize':(15, 4)})
sns.set_style('whitegrid')
sns.set_context('paper')

ax = df_forecast.plot(x_compat=True, style='-')
ax.set_xlabel("Data")
ax.legend(["Real", "Predito"])

plt.grid(True)

plt.show()

plt.close()

sns.set(rc={'figure.figsize':(12, 6)})
sns.set_style('whitegrid')
sns.set_context('paper')

plt.figure(figsize=(15, 4))
plt.hist(y_true, bins=10, color='orange', alpha=0.5, label='Real')
plt.hist(y_hat, bins=10, color='green', alpha=0.5, label='Predito')
plt.legend()

plt.show()

plt.close()

# %%
#toca um som para avisar que terminou de executar
pygame.mixer.init()
arquivo_mp3 = 'support_files/mario_coin.mp3'
pygame.mixer.music.load(arquivo_mp3)
pygame.mixer.music.play()

while pygame.mixer.music.get_busy():
    continue
    
print('Sucesso!')
# Out:
# Sucesso!
